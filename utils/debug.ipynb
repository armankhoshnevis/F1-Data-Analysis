# %%
import os
import pandas as pd

file_path = os.path.join(os.path.dirname(__name__), '..', 'Datasets', 'race_schedule.csv')
df = pd.read_csv(file_path)
# Out:
#      season  round                raceName        date       time  \
# 0      2017      1   Australian Grand Prix  2017-03-26  05:00:00Z
# 1      2017      2      Chinese Grand Prix  2017-04-09  06:00:00Z
# 2      2017      3      Bahrain Grand Prix  2017-04-16  15:00:00Z
# 3      2017      4      Russian Grand Prix  2017-04-30  12:00:00Z
# 4      2017      5      Spanish Grand Prix  2017-05-14  12:00:00Z
# ..      ...    ...                     ...         ...        ...
# 164    2024     20  Mexico City Grand Prix  2024-10-27  20:00:00Z
# 165    2024     21    São Paulo Grand Prix  2024-11-03  17:00:00Z
# 166    2024     22    Las Vegas Grand Prix  2024-11-23  06:00:00Z
# 167    2024     23        Qatar Grand Prix  2024-12-01  17:00:00Z
# 168    2024     24    Abu Dhabi Grand Prix  2024-12-08  13:00:00Z
#
#        circuitId                     circuitName location-locality  \
# 0    albert_park  Albert Park Grand Prix Circuit         Melbourne
# ...
